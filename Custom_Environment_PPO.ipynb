# %% [markdown]
# # Reinforcement Learning
#
# - Author: Rajesh Siraskar
# - Versions:
#     - V 0.1: 31-Oct-2021 | xxxxxxxx | Initial Stable Baselines working version!
#     - V.0.2: 14-Nov-2021 | 02:06 AM | Initial version! Custom environment
#     - V.0.2: 14-Nov-2021 | 11:48 PM | Add TensorBoard!
#     - V.0.3: 15-Nov-2021 | 13:40 PM | Change reqard function to be more realistic (1-position/GRID_SIZE)
#
#
# ### Objectives:
# - Create a simple custom environment
# - Train a PPO agent
# - Tensorboard integration:
#     - In code: Simply add the parameter to enable logging ```tensorboard_log="./tensorboard/"```
#     - On Anaconda CLI prompt:
#         - Activate the conda environment
#         - And it worked in only in ```C:\Users\rajes>```
#         - ```C:\Users\rajes>tensorboard --logdir E:\Projects\RL_PdM\tensorboard\.```

# %%
import numpy as np
import gym
from gym import spaces
import stable_baselines3

from stable_baselines3.common.env_checker import check_env

GRID_SIZE = 100

# %%
class GoLeftEnv(gym.Env):
    """
    Custom Environment that follows gym interface.
    This is a simple env where the agent must learn to go always left. 
    """
    
    # Because of google colab, we cannot implement the GUI ('human' render mode)
    metadata = {'render.modes': ['console']}
    # Define constants for clearer code
    LEFT = 0
    RIGHT = 1
    
    def __init__(self, grid_size=20):
        super(GoLeftEnv, self).__init__()

        # Size of the 1D-grid
        self.grid_size = grid_size
        # Initialize the agent at the right of the grid
        self.agent_pos = grid_size - 1

        # Define action and observation space
        # They must be gym.spaces objects
        # Example when using discrete actions, we have two: left and right
        n_actions = 2
        self.action_space = spaces.Discrete(n_actions)
        # The observation will be the coordinate of the agent
        # this can be described both by Discrete and Box space
        self.observation_space = spaces.Box(low=0, high=self.grid_size,
                                            shape=(1,), dtype=np.float32)
        
    def reset(self):
        """
        Important: the observation must be a numpy array
        :return: (np.array) 
        """

        ## $$$ Rajesh S
        ### ORIGNAL
        # Initialize the agent at the right of the grid
        # self.agent_pos = self.grid_size - 1
        ### ORIGNAL

        ## Initialize to start randomly at some point
        self.agent_pos = np.random.randint(low=0, high=self.grid_size)

        # here we convert to float32 to make it more general (in case we want to use continuous actions)
        return np.array([self.agent_pos]).astype(np.float32)


    def step(self, action):
        if action == self.LEFT:
            self.agent_pos -= 1
        elif action == self.RIGHT:
            self.agent_pos += 1
        else:
            raise ValueError("Received invalid action={} which is not part of the action space".format(action))

        # Account for the boundaries of the grid
        self.agent_pos = np.clip(self.agent_pos, 0, self.grid_size)

        # Are we at the left of the grid?
        done = bool(self.agent_pos == 0)

        # $$$ original
        # Null reward everywhere except when reaching the goal (left of the grid)
        # reward = 1 if self.agent_pos == 0 else 0

        # $$$ Rajesh 
        # (1 - position/Grid_Size) = reward. At last point this is 1-1 = 0, 
        # Other points as close to left it is higher and higher 
        # everywhere except when reaching the goal (left of the grid)
        if self.agent_pos == 0:
            reward = 10     
        else:
            reward = (1.0 -  self.agent_pos/self.grid_size) 

        # Optionally we can pass additional info, we are not using that for now
        info = {}

        return np.array([self.agent_pos]).astype(np.float32), reward, done, info


    def render(self, mode='console'):
        if mode != 'console':
            raise NotImplementedError()
        # agent is represented as a cross, rest as a dot
        print("." * self.agent_pos, end="")
        print("x", end="")
        print("." * (self.grid_size - self.agent_pos))

    def close(self):
        pass

# %%
env = GoLeftEnv()
# If the environment don't follow the interface, an error will be thrown
check_env(env, warn=True)

# %%
env = GoLeftEnv(grid_size=100)

obs = env.reset()
env.render()

print(env.observation_space)
print(env.action_space)
print(env.action_space.sample())

GO_LEFT = 0
GO_RIGHT = 1
# Hardcoded best agent: always go left!

n_steps = 1000
for step in range(n_steps):
    print("Step {}".format(step + 1))
    
    ## $$$ Rajesh S
    ### ORIGNAL: Always go LEFT
    # obs, reward, done, info = env.step(GO_LEFT)
    ### ORIGNAL
   
    ## Random wind
    random_wind = np.random.randint(0, 100)
    if random_wind < 50:
        obs, reward, done, info = env.step(GO_LEFT)
    else:
        obs, reward, done, info = env.step(GO_RIGHT)
        
    print('obs=', obs, 'reward=', reward, 'done=', done)
    env.render()
    if done:
        print("Goal reached!", "reward=", reward)
        break
# Out:
# .........x...........................................................................................
# Box([0.], [100.], (1,), float32)
# Discrete(2)
# 0
# Step 1
# obs= [10.] reward= 0.9 done= False
# ..........x..........................................................................................
# Step 2
# obs= [11.] reward= 0.89 done= False
# ...........x.........................................................................................
# Step 3
# obs= [12.] reward= 0.88 done= False
# ............x........................................................................................
# Step 4
# obs= [13.] reward= 0.87 done= False
# .............x.......................................................................................
# Step 5
# obs= [12.] reward= 0.88 done= False
# ............x........................................................................................
# Step 6
# obs= [13.] reward= 0.87 done= False
# .............x.......................................................................................
# Step 7
# obs= [12.] reward= 0.88 done= False
# ............x........................................................................................
# Step 8
# obs= [11.] reward= 0.89 done= False
# ...........x.........................................................................................
# Step 9
# obs= [12.] reward= 0.88 done= False
# ............x........................................................................................
# Step 10
# obs= [13.] reward= 0.87 done= False
# .............x.......................................................................................
# Step 11
# obs= [14.] reward= 0.86 done= False
# ..............x......................................................................................
# Step 12
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 13
# obs= [14.] reward= 0.86 done= False
# ..............x......................................................................................
# Step 14
# obs= [13.] reward= 0.87 done= False
# .............x.......................................................................................
# Step 15
# obs= [12.] reward= 0.88 done= False
# ............x........................................................................................
# Step 16
# obs= [11.] reward= 0.89 done= False
# ...........x.........................................................................................
# Step 17
# obs= [10.] reward= 0.9 done= False
# ..........x..........................................................................................
# Step 18
# obs= [11.] reward= 0.89 done= False
# ...........x.........................................................................................
# Step 19
# obs= [10.] reward= 0.9 done= False
# ..........x..........................................................................................
# Step 20
# obs= [9.] reward= 0.91 done= False
# .........x...........................................................................................
# Step 21
# obs= [10.] reward= 0.9 done= False
# ..........x..........................................................................................
# Step 22
# obs= [11.] reward= 0.89 done= False
# ...........x.........................................................................................
# Step 23
# obs= [12.] reward= 0.88 done= False
# ............x........................................................................................
# Step 24
# obs= [13.] reward= 0.87 done= False
# .............x.......................................................................................
# Step 25
# obs= [12.] reward= 0.88 done= False
# ............x........................................................................................
# Step 26
# obs= [11.] reward= 0.89 done= False
# ...........x.........................................................................................
# Step 27
# obs= [10.] reward= 0.9 done= False
# ..........x..........................................................................................
# Step 28
# obs= [11.] reward= 0.89 done= False
# ...........x.........................................................................................
# Step 29
# obs= [10.] reward= 0.9 done= False
# ..........x..........................................................................................
# Step 30
# obs= [9.] reward= 0.91 done= False
# .........x...........................................................................................
# Step 31
# obs= [10.] reward= 0.9 done= False
# ..........x..........................................................................................
# Step 32
# obs= [11.] reward= 0.89 done= False
# ...........x.........................................................................................
# Step 33
# obs= [12.] reward= 0.88 done= False
# ............x........................................................................................
# Step 34
# obs= [13.] reward= 0.87 done= False
# .............x.......................................................................................
# Step 35
# obs= [14.] reward= 0.86 done= False
# ..............x......................................................................................
# Step 36
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 37
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 38
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 39
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 40
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 41
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 42
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 43
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 44
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 45
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 46
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 47
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 48
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 49
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 50
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 51
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 52
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 53
# obs= [20.] reward= 0.8 done= False
# ....................x................................................................................
# Step 54
# obs= [21.] reward= 0.79 done= False
# .....................x...............................................................................
# Step 55
# obs= [22.] reward= 0.78 done= False
# ......................x..............................................................................
# Step 56
# obs= [23.] reward= 0.77 done= False
# .......................x.............................................................................
# Step 57
# obs= [22.] reward= 0.78 done= False
# ......................x..............................................................................
# Step 58
# obs= [23.] reward= 0.77 done= False
# .......................x.............................................................................
# Step 59
# obs= [22.] reward= 0.78 done= False
# ......................x..............................................................................
# Step 60
# obs= [23.] reward= 0.77 done= False
# .......................x.............................................................................
# Step 61
# obs= [24.] reward= 0.76 done= False
# ........................x............................................................................
# Step 62
# obs= [25.] reward= 0.75 done= False
# .........................x...........................................................................
# Step 63
# obs= [24.] reward= 0.76 done= False
# ........................x............................................................................
# Step 64
# obs= [23.] reward= 0.77 done= False
# .......................x.............................................................................
# Step 65
# obs= [22.] reward= 0.78 done= False
# ......................x..............................................................................
# Step 66
# obs= [21.] reward= 0.79 done= False
# .....................x...............................................................................
# Step 67
# obs= [22.] reward= 0.78 done= False
# ......................x..............................................................................
# Step 68
# obs= [23.] reward= 0.77 done= False
# .......................x.............................................................................
# Step 69
# obs= [24.] reward= 0.76 done= False
# ........................x............................................................................
# Step 70
# obs= [25.] reward= 0.75 done= False
# .........................x...........................................................................
# Step 71
# obs= [26.] reward= 0.74 done= False
# ..........................x..........................................................................
# Step 72
# obs= [27.] reward= 0.73 done= False
# ...........................x.........................................................................
# Step 73
# obs= [28.] reward= 0.72 done= False
# ............................x........................................................................
# Step 74
# obs= [29.] reward= 0.71 done= False
# .............................x.......................................................................
# Step 75
# obs= [30.] reward= 0.7 done= False
# ..............................x......................................................................
# Step 76
# obs= [29.] reward= 0.71 done= False
# .............................x.......................................................................
# Step 77
# obs= [28.] reward= 0.72 done= False
# ............................x........................................................................
# Step 78
# obs= [29.] reward= 0.71 done= False
# .............................x.......................................................................
# Step 79
# obs= [30.] reward= 0.7 done= False
# ..............................x......................................................................
# Step 80
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 81
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 82
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 83
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 84
# obs= [33.] reward= 0.6699999999999999 done= False
# .................................x...................................................................
# Step 85
# obs= [34.] reward= 0.6599999999999999 done= False
# ..................................x..................................................................
# Step 86
# obs= [35.] reward= 0.65 done= False
# ...................................x.................................................................
# Step 87
# obs= [36.] reward= 0.64 done= False
# ....................................x................................................................
# Step 88
# obs= [37.] reward= 0.63 done= False
# .....................................x...............................................................
# Step 89
# obs= [38.] reward= 0.62 done= False
# ......................................x..............................................................
# Step 90
# obs= [37.] reward= 0.63 done= False
# .....................................x...............................................................
# Step 91
# obs= [38.] reward= 0.62 done= False
# ......................................x..............................................................
# Step 92
# obs= [39.] reward= 0.61 done= False
# .......................................x.............................................................
# Step 93
# obs= [38.] reward= 0.62 done= False
# ......................................x..............................................................
# Step 94
# obs= [39.] reward= 0.61 done= False
# .......................................x.............................................................
# Step 95
# obs= [38.] reward= 0.62 done= False
# ......................................x..............................................................
# Step 96
# obs= [37.] reward= 0.63 done= False
# .....................................x...............................................................
# Step 97
# obs= [36.] reward= 0.64 done= False
# ....................................x................................................................
# Step 98
# obs= [37.] reward= 0.63 done= False
# .....................................x...............................................................
# Step 99
# obs= [36.] reward= 0.64 done= False
# ....................................x................................................................
# Step 100
# obs= [37.] reward= 0.63 done= False
# .....................................x...............................................................
# Step 101
# obs= [36.] reward= 0.64 done= False
# ....................................x................................................................
# Step 102
# obs= [35.] reward= 0.65 done= False
# ...................................x.................................................................
# Step 103
# obs= [34.] reward= 0.6599999999999999 done= False
# ..................................x..................................................................
# Step 104
# obs= [33.] reward= 0.6699999999999999 done= False
# .................................x...................................................................
# Step 105
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 106
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 107
# obs= [30.] reward= 0.7 done= False
# ..............................x......................................................................
# Step 108
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 109
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 110
# obs= [33.] reward= 0.6699999999999999 done= False
# .................................x...................................................................
# Step 111
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 112
# obs= [33.] reward= 0.6699999999999999 done= False
# .................................x...................................................................
# Step 113
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 114
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 115
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 116
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 117
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 118
# obs= [33.] reward= 0.6699999999999999 done= False
# .................................x...................................................................
# Step 119
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 120
# obs= [33.] reward= 0.6699999999999999 done= False
# .................................x...................................................................
# Step 121
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 122
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 123
# obs= [30.] reward= 0.7 done= False
# ..............................x......................................................................
# Step 124
# obs= [29.] reward= 0.71 done= False
# .............................x.......................................................................
# Step 125
# obs= [28.] reward= 0.72 done= False
# ............................x........................................................................
# Step 126
# obs= [29.] reward= 0.71 done= False
# .............................x.......................................................................
# Step 127
# obs= [30.] reward= 0.7 done= False
# ..............................x......................................................................
# Step 128
# obs= [29.] reward= 0.71 done= False
# .............................x.......................................................................
# Step 129
# obs= [30.] reward= 0.7 done= False
# ..............................x......................................................................
# Step 130
# obs= [29.] reward= 0.71 done= False
# .............................x.......................................................................
# Step 131
# obs= [28.] reward= 0.72 done= False
# ............................x........................................................................
# Step 132
# obs= [29.] reward= 0.71 done= False
# .............................x.......................................................................
# Step 133
# obs= [28.] reward= 0.72 done= False
# ............................x........................................................................
# Step 134
# obs= [29.] reward= 0.71 done= False
# .............................x.......................................................................
# Step 135
# obs= [28.] reward= 0.72 done= False
# ............................x........................................................................
# Step 136
# obs= [29.] reward= 0.71 done= False
# .............................x.......................................................................
# Step 137
# obs= [30.] reward= 0.7 done= False
# ..............................x......................................................................
# Step 138
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 139
# obs= [30.] reward= 0.7 done= False
# ..............................x......................................................................
# Step 140
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 141
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 142
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 143
# obs= [30.] reward= 0.7 done= False
# ..............................x......................................................................
# Step 144
# obs= [29.] reward= 0.71 done= False
# .............................x.......................................................................
# Step 145
# obs= [28.] reward= 0.72 done= False
# ............................x........................................................................
# Step 146
# obs= [27.] reward= 0.73 done= False
# ...........................x.........................................................................
# Step 147
# obs= [26.] reward= 0.74 done= False
# ..........................x..........................................................................
# Step 148
# obs= [25.] reward= 0.75 done= False
# .........................x...........................................................................
# Step 149
# obs= [26.] reward= 0.74 done= False
# ..........................x..........................................................................
# Step 150
# obs= [25.] reward= 0.75 done= False
# .........................x...........................................................................
# Step 151
# obs= [26.] reward= 0.74 done= False
# ..........................x..........................................................................
# Step 152
# obs= [25.] reward= 0.75 done= False
# .........................x...........................................................................
# Step 153
# obs= [24.] reward= 0.76 done= False
# ........................x............................................................................
# Step 154
# obs= [25.] reward= 0.75 done= False
# .........................x...........................................................................
# Step 155
# obs= [26.] reward= 0.74 done= False
# ..........................x..........................................................................
# Step 156
# obs= [25.] reward= 0.75 done= False
# .........................x...........................................................................
# Step 157
# obs= [24.] reward= 0.76 done= False
# ........................x............................................................................
# Step 158
# obs= [25.] reward= 0.75 done= False
# .........................x...........................................................................
# Step 159
# obs= [26.] reward= 0.74 done= False
# ..........................x..........................................................................
# Step 160
# obs= [27.] reward= 0.73 done= False
# ...........................x.........................................................................
# Step 161
# obs= [26.] reward= 0.74 done= False
# ..........................x..........................................................................
# Step 162
# obs= [27.] reward= 0.73 done= False
# ...........................x.........................................................................
# Step 163
# obs= [28.] reward= 0.72 done= False
# ............................x........................................................................
# Step 164
# obs= [29.] reward= 0.71 done= False
# .............................x.......................................................................
# Step 165
# obs= [30.] reward= 0.7 done= False
# ..............................x......................................................................
# Step 166
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 167
# obs= [30.] reward= 0.7 done= False
# ..............................x......................................................................
# Step 168
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 169
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 170
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 171
# obs= [30.] reward= 0.7 done= False
# ..............................x......................................................................
# Step 172
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 173
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 174
# obs= [31.] reward= 0.69 done= False
# ...............................x.....................................................................
# Step 175
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 176
# obs= [33.] reward= 0.6699999999999999 done= False
# .................................x...................................................................
# Step 177
# obs= [34.] reward= 0.6599999999999999 done= False
# ..................................x..................................................................
# Step 178
# obs= [33.] reward= 0.6699999999999999 done= False
# .................................x...................................................................
# Step 179
# obs= [34.] reward= 0.6599999999999999 done= False
# ..................................x..................................................................
# Step 180
# obs= [35.] reward= 0.65 done= False
# ...................................x.................................................................
# Step 181
# obs= [34.] reward= 0.6599999999999999 done= False
# ..................................x..................................................................
# Step 182
# obs= [33.] reward= 0.6699999999999999 done= False
# .................................x...................................................................
# Step 183
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 184
# obs= [33.] reward= 0.6699999999999999 done= False
# .................................x...................................................................
# Step 185
# obs= [32.] reward= 0.6799999999999999 done= False
# ................................x....................................................................
# Step 186
# obs= [33.] reward= 0.6699999999999999 done= False
# .................................x...................................................................
# Step 187
# obs= [34.] reward= 0.6599999999999999 done= False
# ..................................x..................................................................
# Step 188
# obs= [33.] reward= 0.6699999999999999 done= False
# .................................x...................................................................
# Step 189
# obs= [34.] reward= 0.6599999999999999 done= False
# ..................................x..................................................................
# Step 190
# obs= [35.] reward= 0.65 done= False
# ...................................x.................................................................
# Step 191
# obs= [36.] reward= 0.64 done= False
# ....................................x................................................................
# Step 192
# obs= [35.] reward= 0.65 done= False
# ...................................x.................................................................
# Step 193
# obs= [34.] reward= 0.6599999999999999 done= False
# ..................................x..................................................................
# Step 194
# obs= [35.] reward= 0.65 done= False
# ...................................x.................................................................
# Step 195
# obs= [36.] reward= 0.64 done= False
# ....................................x................................................................
# Step 196
# obs= [35.] reward= 0.65 done= False
# ...................................x.................................................................
# Step 197
# obs= [36.] reward= 0.64 done= False
# ....................................x................................................................
# Step 198
# obs= [37.] reward= 0.63 done= False
# .....................................x...............................................................
# Step 199
# obs= [36.] reward= 0.64 done= False
# ....................................x................................................................
# Step 200
# obs= [37.] reward= 0.63 done= False
# .....................................x...............................................................
# Step 201
# obs= [38.] reward= 0.62 done= False
# ......................................x..............................................................
# Step 202
# obs= [39.] reward= 0.61 done= False
# .......................................x.............................................................
# Step 203
# obs= [38.] reward= 0.62 done= False
# ......................................x..............................................................
# Step 204
# obs= [37.] reward= 0.63 done= False
# .....................................x...............................................................
# Step 205
# obs= [38.] reward= 0.62 done= False
# ......................................x..............................................................
# Step 206
# obs= [37.] reward= 0.63 done= False
# .....................................x...............................................................
# Step 207
# obs= [36.] reward= 0.64 done= False
# ....................................x................................................................
# Step 208
# obs= [37.] reward= 0.63 done= False
# .....................................x...............................................................
# Step 209
# obs= [36.] reward= 0.64 done= False
# ....................................x................................................................
# Step 210
# obs= [35.] reward= 0.65 done= False
# ...................................x.................................................................
# Step 211
# obs= [36.] reward= 0.64 done= False
# ....................................x................................................................
# Step 212
# obs= [37.] reward= 0.63 done= False
# .....................................x...............................................................
# Step 213
# obs= [38.] reward= 0.62 done= False
# ......................................x..............................................................
# Step 214
# obs= [39.] reward= 0.61 done= False
# .......................................x.............................................................
# Step 215
# obs= [40.] reward= 0.6 done= False
# ........................................x............................................................
# Step 216
# obs= [41.] reward= 0.5900000000000001 done= False
# .........................................x...........................................................
# Step 217
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 218
# obs= [41.] reward= 0.5900000000000001 done= False
# .........................................x...........................................................
# Step 219
# obs= [40.] reward= 0.6 done= False
# ........................................x............................................................
# Step 220
# obs= [41.] reward= 0.5900000000000001 done= False
# .........................................x...........................................................
# Step 221
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 222
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 223
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 224
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 225
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 226
# obs= [41.] reward= 0.5900000000000001 done= False
# .........................................x...........................................................
# Step 227
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 228
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 229
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 230
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 231
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 232
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 233
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 234
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 235
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 236
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 237
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 238
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 239
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 240
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 241
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 242
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 243
# obs= [48.] reward= 0.52 done= False
# ................................................x....................................................
# Step 244
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 245
# obs= [48.] reward= 0.52 done= False
# ................................................x....................................................
# Step 246
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 247
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 248
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 249
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 250
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 251
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 252
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 253
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 254
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 255
# obs= [48.] reward= 0.52 done= False
# ................................................x....................................................
# Step 256
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 257
# obs= [48.] reward= 0.52 done= False
# ................................................x....................................................
# Step 258
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 259
# obs= [48.] reward= 0.52 done= False
# ................................................x....................................................
# Step 260
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 261
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 262
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 263
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 264
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 265
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 266
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 267
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 268
# obs= [41.] reward= 0.5900000000000001 done= False
# .........................................x...........................................................
# Step 269
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 270
# obs= [41.] reward= 0.5900000000000001 done= False
# .........................................x...........................................................
# Step 271
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 272
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 273
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 274
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 275
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 276
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 277
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 278
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 279
# obs= [48.] reward= 0.52 done= False
# ................................................x....................................................
# Step 280
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 281
# obs= [48.] reward= 0.52 done= False
# ................................................x....................................................
# Step 282
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 283
# obs= [48.] reward= 0.52 done= False
# ................................................x....................................................
# Step 284
# obs= [47.] reward= 0.53 done= False
# ...............................................x.....................................................
# Step 285
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 286
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 287
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 288
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 289
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 290
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 291
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 292
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 293
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 294
# obs= [41.] reward= 0.5900000000000001 done= False
# .........................................x...........................................................
# Step 295
# obs= [40.] reward= 0.6 done= False
# ........................................x............................................................
# Step 296
# obs= [41.] reward= 0.5900000000000001 done= False
# .........................................x...........................................................
# Step 297
# obs= [40.] reward= 0.6 done= False
# ........................................x............................................................
# Step 298
# obs= [41.] reward= 0.5900000000000001 done= False
# .........................................x...........................................................
# Step 299
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 300
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 301
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 302
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 303
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 304
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 305
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 306
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 307
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 308
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 309
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 310
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 311
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 312
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 313
# obs= [46.] reward= 0.54 done= False
# ..............................................x......................................................
# Step 314
# obs= [45.] reward= 0.55 done= False
# .............................................x.......................................................
# Step 315
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 316
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 317
# obs= [42.] reward= 0.5800000000000001 done= False
# ..........................................x..........................................................
# Step 318
# obs= [43.] reward= 0.5700000000000001 done= False
# ...........................................x.........................................................
# Step 319
# obs= [44.] reward= 0.56 done= False
# ............................................x........................................................
# Step 320
# ...
# ................x....................................................................................
# Step 894
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 895
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 896
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 897
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 898
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 899
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 900
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 901
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 902
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 903
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 904
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 905
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 906
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 907
# obs= [20.] reward= 0.8 done= False
# ....................x................................................................................
# Step 908
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 909
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 910
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 911
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 912
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 913
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 914
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 915
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 916
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 917
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 918
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 919
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 920
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 921
# obs= [14.] reward= 0.86 done= False
# ..............x......................................................................................
# Step 922
# obs= [13.] reward= 0.87 done= False
# .............x.......................................................................................
# Step 923
# obs= [12.] reward= 0.88 done= False
# ............x........................................................................................
# Step 924
# obs= [11.] reward= 0.89 done= False
# ...........x.........................................................................................
# Step 925
# obs= [10.] reward= 0.9 done= False
# ..........x..........................................................................................
# Step 926
# obs= [11.] reward= 0.89 done= False
# ...........x.........................................................................................
# Step 927
# obs= [10.] reward= 0.9 done= False
# ..........x..........................................................................................
# Step 928
# obs= [11.] reward= 0.89 done= False
# ...........x.........................................................................................
# Step 929
# obs= [12.] reward= 0.88 done= False
# ............x........................................................................................
# Step 930
# obs= [13.] reward= 0.87 done= False
# .............x.......................................................................................
# Step 931
# obs= [14.] reward= 0.86 done= False
# ..............x......................................................................................
# Step 932
# obs= [13.] reward= 0.87 done= False
# .............x.......................................................................................
# Step 933
# obs= [14.] reward= 0.86 done= False
# ..............x......................................................................................
# Step 934
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 935
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 936
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 937
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 938
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 939
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 940
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 941
# obs= [14.] reward= 0.86 done= False
# ..............x......................................................................................
# Step 942
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 943
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 944
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 945
# obs= [14.] reward= 0.86 done= False
# ..............x......................................................................................
# Step 946
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 947
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 948
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 949
# obs= [14.] reward= 0.86 done= False
# ..............x......................................................................................
# Step 950
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 951
# obs= [14.] reward= 0.86 done= False
# ..............x......................................................................................
# Step 952
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 953
# obs= [14.] reward= 0.86 done= False
# ..............x......................................................................................
# Step 954
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 955
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 956
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 957
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 958
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 959
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 960
# obs= [15.] reward= 0.85 done= False
# ...............x.....................................................................................
# Step 961
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 962
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 963
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 964
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 965
# obs= [20.] reward= 0.8 done= False
# ....................x................................................................................
# Step 966
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 967
# obs= [20.] reward= 0.8 done= False
# ....................x................................................................................
# Step 968
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 969
# obs= [20.] reward= 0.8 done= False
# ....................x................................................................................
# Step 970
# obs= [21.] reward= 0.79 done= False
# .....................x...............................................................................
# Step 971
# obs= [20.] reward= 0.8 done= False
# ....................x................................................................................
# Step 972
# obs= [21.] reward= 0.79 done= False
# .....................x...............................................................................
# Step 973
# obs= [20.] reward= 0.8 done= False
# ....................x................................................................................
# Step 974
# obs= [21.] reward= 0.79 done= False
# .....................x...............................................................................
# Step 975
# obs= [22.] reward= 0.78 done= False
# ......................x..............................................................................
# Step 976
# obs= [21.] reward= 0.79 done= False
# .....................x...............................................................................
# Step 977
# obs= [20.] reward= 0.8 done= False
# ....................x................................................................................
# Step 978
# obs= [21.] reward= 0.79 done= False
# .....................x...............................................................................
# Step 979
# obs= [20.] reward= 0.8 done= False
# ....................x................................................................................
# Step 980
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 981
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 982
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 983
# obs= [20.] reward= 0.8 done= False
# ....................x................................................................................
# Step 984
# obs= [21.] reward= 0.79 done= False
# .....................x...............................................................................
# Step 985
# obs= [20.] reward= 0.8 done= False
# ....................x................................................................................
# Step 986
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 987
# obs= [20.] reward= 0.8 done= False
# ....................x................................................................................
# Step 988
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 989
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 990
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 991
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 992
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 993
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 994
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 995
# obs= [16.] reward= 0.84 done= False
# ................x....................................................................................
# Step 996
# obs= [17.] reward= 0.83 done= False
# .................x...................................................................................
# Step 997
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 998
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................
# Step 999
# obs= [18.] reward= 0.8200000000000001 done= False
# ..................x..................................................................................
# Step 1000
# obs= [19.] reward= 0.81 done= False
# ...................x.................................................................................

# %%
from stable_baselines3 import DQN, PPO, A2C
from stable_baselines3.common.cmd_util import make_vec_env

# Instantiate the env
env = GoLeftEnv(grid_size=GRID_SIZE)
# wrap it
env = make_vec_env(lambda: env, n_envs=1)

# %%
# Train the agent
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log="./tensorboard/")
model.learn(10000)
# Out:
# Using cpu device
# Logging to ./tensorboard/DQN_2

# %%
# Test the trained agent
obs = env.reset()
n_steps = 20
for step in range(n_steps):
  action, _ = model.predict(obs, deterministic=True)
  print("Step {}".format(step + 1))
  print("Action: ", action)
  obs, reward, done, info = env.step(action)
  print('obs=', obs, 'reward=', reward, 'done=', done)
  env.render(mode='console')
  if done:
    # Note that the VecEnv resets automatically
    # when a done signal is encountered
    print("Goal reached!", "reward=", reward)
    break
# Out:
# Step 1
# Action:  [0]
# obs= [[73.]] reward= [0.27] done= [False]
# .........................................................................x...........................
# Step 2
# Action:  [0]
# obs= [[72.]] reward= [0.28] done= [False]
# ........................................................................x............................
# Step 3
# Action:  [0]
# obs= [[71.]] reward= [0.29] done= [False]
# .......................................................................x.............................
# Step 4
# Action:  [0]
# obs= [[70.]] reward= [0.3] done= [False]
# ......................................................................x..............................
# Step 5
# Action:  [0]
# obs= [[69.]] reward= [0.31] done= [False]
# .....................................................................x...............................
# Step 6
# Action:  [0]
# obs= [[68.]] reward= [0.32] done= [False]
# ....................................................................x................................
# Step 7
# Action:  [0]
# obs= [[67.]] reward= [0.33] done= [False]
# ...................................................................x.................................
# Step 8
# Action:  [0]
# obs= [[66.]] reward= [0.34] done= [False]
# ..................................................................x..................................
# Step 9
# Action:  [0]
# obs= [[65.]] reward= [0.35] done= [False]
# .................................................................x...................................
# Step 10
# Action:  [0]
# obs= [[64.]] reward= [0.36] done= [False]
# ................................................................x....................................
# Step 11
# Action:  [0]
# obs= [[63.]] reward= [0.37] done= [False]
# ...............................................................x.....................................
# Step 12
# Action:  [0]
# obs= [[62.]] reward= [0.38] done= [False]
# ..............................................................x......................................
# Step 13
# Action:  [0]
# obs= [[61.]] reward= [0.39] done= [False]
# .............................................................x.......................................
# Step 14
# Action:  [0]
# obs= [[60.]] reward= [0.4] done= [False]
# ............................................................x........................................
# Step 15
# Action:  [0]
# obs= [[59.]] reward= [0.41] done= [False]
# ...........................................................x.........................................
# Step 16
# Action:  [0]
# obs= [[58.]] reward= [0.42] done= [False]
# ..........................................................x..........................................
# Step 17
# Action:  [0]
# obs= [[57.]] reward= [0.43] done= [False]
# .........................................................x...........................................
# Step 18
# Action:  [0]
# obs= [[56.]] reward= [0.44] done= [False]
# ........................................................x............................................
# Step 19
# Action:  [0]
# obs= [[55.]] reward= [0.45] done= [False]
# .......................................................x.............................................
# Step 20
# Action:  [0]
# obs= [[54.]] reward= [0.46] done= [False]
# ......................................................x..............................................
